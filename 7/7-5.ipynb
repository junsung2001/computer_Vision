# %% [markdown]
# # 깊은 다층 퍼셉트론으로 MNIST 손글씨 인식
# - 데이터 전처리, 모델 정의, 학습, 평가, 시각화 진행

# %% [markdown]
# ## 라이브러리 불러오기

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
ds.mnist
# Out:
# <module 'keras.datasets.mnist' from 'c:\\anaconda\\envs\\cv\\Lib\\site-packages\\keras\\datasets\\mnist\\__init__.py'>

# %% [markdown]
# ## 데이터 전처리
#
# - MNIST 데이터셋 불러오기 및 전처리
# - 데이터는 28x28 흑백 이미지를 1차원 벡터(784차원)로 변환
# - 픽셀 값을 [0, 1] 범위로 정규화
# - 레이블을 원-핫 인코딩으로 변환

# %%
(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()

# 데이터 정규화 및 1차원 벡터로 변환
x_train = x_train.reshape(60000, 784).astype(np.float32) / 255.0
x_test = x_test.reshape(10000, 784).astype(np.float32) / 255.0

# 레이블을 원-핫 인코딩으로 변환
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
dmlp = Sequential()
dmlp.add(Input(shape=(784,)))
dmlp.add(Dense(units=1024, activation='relu'))
dmlp.add(Dropout(0.4))
dmlp.add(Dense(units=512, activation='relu'))
dmlp.add(Dropout(0.4))
dmlp.add(Dense(units=512, activation='relu'))
dmlp.add(Dropout(0.4))
dmlp.add(Dense(units=10, activation='softmax'))

# %% [markdown]
# ## 모델 컴파일 및 학습
#
# - 손실 함수: categorical_crossentropy (다중 클래스 분류)
# - 옵티마이저: Adam
# - 평가 지표: accuracy
# - 배치 크기 : 128, 에포크 : 50 으로 학습 진행

# %%
dmlp.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])
hist = dmlp.fit(x_train, y_train, batch_size=128, epochs=30, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/30
# 469/469 - 11s - 24ms/step - accuracy: 0.8407 - loss: 0.6048 - val_accuracy: 0.9342 - val_loss: 0.2820
# Epoch 2/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8635 - loss: 0.5761 - val_accuracy: 0.9381 - val_loss: 0.2521
# Epoch 3/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8686 - loss: 0.5669 - val_accuracy: 0.9400 - val_loss: 0.2950
# Epoch 4/30
# 469/469 - 9s - 18ms/step - accuracy: 0.8649 - loss: 0.5975 - val_accuracy: 0.9272 - val_loss: 0.3121
# Epoch 5/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8626 - loss: 0.6153 - val_accuracy: 0.9320 - val_loss: 0.3722
# Epoch 6/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8612 - loss: 0.6129 - val_accuracy: 0.9318 - val_loss: 0.3355
# Epoch 7/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8706 - loss: 0.5629 - val_accuracy: 0.9333 - val_loss: 0.3062
# Epoch 8/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8692 - loss: 0.5764 - val_accuracy: 0.9356 - val_loss: 0.3104
# Epoch 9/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8671 - loss: 0.5815 - val_accuracy: 0.9383 - val_loss: 0.3481
# Epoch 10/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8709 - loss: 0.5612 - val_accuracy: 0.9192 - val_loss: 0.4508
# Epoch 11/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8631 - loss: 0.6021 - val_accuracy: 0.9219 - val_loss: 0.3733
# Epoch 12/30
# 469/469 - 9s - 18ms/step - accuracy: 0.8665 - loss: 0.5980 - val_accuracy: 0.9344 - val_loss: 0.3380
# Epoch 13/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8676 - loss: 0.5535 - val_accuracy: 0.9345 - val_loss: 0.3119
# Epoch 14/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8794 - loss: 0.5412 - val_accuracy: 0.9324 - val_loss: 0.3163
# Epoch 15/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8646 - loss: 0.5932 - val_accuracy: 0.9229 - val_loss: 0.3947
# Epoch 16/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8718 - loss: 0.5712 - val_accuracy: 0.9376 - val_loss: 0.3498
# Epoch 17/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8615 - loss: 0.5947 - val_accuracy: 0.9420 - val_loss: 0.3301
# Epoch 18/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8708 - loss: 0.5506 - val_accuracy: 0.9296 - val_loss: 0.3550
# Epoch 19/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8661 - loss: 0.5905 - val_accuracy: 0.9397 - val_loss: 0.3338
# Epoch 20/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8684 - loss: 0.5446 - val_accuracy: 0.9367 - val_loss: 0.3468
# Epoch 21/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8684 - loss: 0.5513 - val_accuracy: 0.9169 - val_loss: 0.3864
# Epoch 22/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8647 - loss: 0.6012 - val_accuracy: 0.9338 - val_loss: 0.3915
# Epoch 23/30
# 469/469 - 9s - 18ms/step - accuracy: 0.8543 - loss: 0.6218 - val_accuracy: 0.9304 - val_loss: 0.4055
# Epoch 24/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8634 - loss: 0.5929 - val_accuracy: 0.9377 - val_loss: 0.4441
# Epoch 25/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8641 - loss: 0.5822 - val_accuracy: 0.9210 - val_loss: 0.4195
# Epoch 26/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8544 - loss: 0.6067 - val_accuracy: 0.9230 - val_loss: 0.5118
# Epoch 27/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8582 - loss: 0.6316 - val_accuracy: 0.9261 - val_loss: 0.5390
# Epoch 28/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8575 - loss: 0.6518 - val_accuracy: 0.9261 - val_loss: 0.5041
# Epoch 29/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8590 - loss: 0.6332 - val_accuracy: 0.9268 - val_loss: 0.3934
# Epoch 30/30
# 469/469 - 8s - 18ms/step - accuracy: 0.8642 - loss: 0.5894 - val_accuracy: 0.9253 - val_loss: 0.5187

# %% [markdown]
# ## 모델 평가

# %%
accuracy = dmlp.evaluate(x_test, y_test, verbose=0)[1] * 100
print(f'정확률 = {accuracy:.2f}%')
# Out:
# 정확률 = 92.53%

# %% [markdown]
# ## 모델 저장

# %%
dmlp.save('dmlp_trained.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## 모델 시각화

# %%
# 정확도 그래프
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy graph')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['train', 'test'])
plt.grid()
plt.show()

# 손실 그래프
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss graph')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'test'])
plt.grid()
plt.show()
